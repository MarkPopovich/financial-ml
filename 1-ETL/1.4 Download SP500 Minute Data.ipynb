# %% [markdown]
# # 1.4 Download SP500 Minute Data
#
# In this notebook we will consider an alternative question. Instead of asking how we can maximize profit on a single asset, we will ask whether a machine can pick the best assets given many selections.
#
# We will consider only price history data. We will provide 90 differenced timesteps on the minute interval period. We will choose the 500 stocks of the S&P 500.
#
# If our network can outperform the S&P 500 over the given time, we will consider it successful.
#
# In order to do this, we will need to perform the following steps:
#
# - download datasets for all the stocks in the S&P 500.
# - format the data to represent the simulataneous movement of 500 stocks
# - Build an environment to represent this movement
# - Train a DQN to learn on it

# %% [markdown]
# #### Download datasets for all the stocks in the S&P 500.

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 8.7 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.2

# %%
import time
from IPython import display
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import os
import sys
from os import listdir
from os.path import isfile, join

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
module_path
# Out:
# '/home/jovyan/work'

# %%
from modules.extract import extract_stock, extract_multi_periods, load_set
from modules.transform import format_date
from modules.sine_modules import *

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
data_dir = '../data/sp500/'
suffix = ''

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
df['Symbol'] = df['Symbol'].str.replace('.','')
df.to_csv('../data/sp500/S&P500-Info.csv')
df.to_csv('../data/sp500/S&P500-Symbols.csv', columns=['Symbol'])
print(df.shape)
df.head()
# Out:
# (505, 9)
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
df[df['Symbol'] =='BRKB']
# Out:
#    Symbol            Security SEC filings GICS Sector      GICS Sub Industry  \
# 66   BRKB  Berkshire Hathaway     reports  Financials  Multi-Sector Holdings
#
#    Headquarters Location Date first added      CIK Founded
# 66       Omaha, Nebraska       2010-02-16  1067983    1839

# %%
stocksdf = df

# %%
data_dir = '../data/sp500/'
stocks = list(stocksdf['Symbol'])
spdf = pd.DataFrame()

# %%
stock = stocks[0]
df = extract_multi_periods(stock, 
                       data_dir=data_dir)

drop = ['date','hour','minute','min_num','SYMBOL','prev_close','diff_1','pct_change','log_return']
df = df.drop(drop, axis=1)
df = df.set_index('datetime')
col_names = {col:f'{stock}_{col}' for col in df.columns}
df = df.rename(col_names, axis=1)
df.head()
# Out:
#                      MMM_open  MMM_high  MMM_low  MMM_close  MMM_volume
# datetime
# 2020-09-15 19:47:00    166.54   166.580  166.495    166.495        4955
# 2020-09-15 19:46:00    166.59   166.590  166.530    166.560        2222
# 2020-09-15 19:45:00    166.52   166.600  166.465    166.580        5114
# 2020-09-15 19:44:00    166.55   166.565  166.510    166.540        2747
# 2020-09-15 19:43:00    166.63   166.630  166.540    166.580        2499

# %%
len(stocks)
# Out:
# 505

# %%
com_stocks = []

# %%
start_time = time.time()

for i, stock in enumerate(stocks):
    if stock in [f.split('.')[0] for f in listdir(data_dir) if isfile(join(data_dir, f))]:
        continue
    df = extract_multi_periods(stock, 
                       data_dir=data_dir)
    
    drop = ['date','hour','minute','min_num','SYMBOL','prev_close','diff_1','pct_change','log_return']
    df = df.drop(drop, axis=1)
    df = df.set_index('datetime')
    col_names = {col:f'{stock}_{col}' for col in df.columns}
    df = df.rename(col_names, axis=1)

    spdf = spdf.join(df, how='outer')
    
    display.clear_output()
    print(f'{i}')
    
    time.sleep(.5)
    
spdf.head()
# Out:
# 504
#                      MMM_open  MMM_high  MMM_low  MMM_close  MMM_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      ABT_open  ABT_high  ABT_low  ABT_close  ABT_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      ABBV_open  ABBV_high  ABBV_low  ABBV_close  ABBV_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      ABMD_open  ABMD_high  ABMD_low  ABMD_close  ABMD_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      ACN_open  ACN_high  ACN_low  ACN_close  ACN_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      ATVI_open  ATVI_high  ATVI_low  ATVI_close  ATVI_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      ADBE_open  ADBE_high  ADBE_low  ADBE_close  ADBE_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      AMD_open  AMD_high  AMD_low  AMD_close  AMD_volume  \
# datetime
# 2020-08-17 08:00:00      81.5      81.5     81.5       81.5       609.0
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      AAP_open  AAP_high  AAP_low  AAP_close  AAP_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      AES_open  AES_high  AES_low  AES_close  AES_volume  ...  \
# datetime                                                                 ...
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN  ...
#
#                      WYNN_open  WYNN_high  WYNN_low  WYNN_close  WYNN_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      XEL_open  XEL_high  XEL_low  XEL_close  XEL_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      XRX_open  XRX_high  XRX_low  XRX_close  XRX_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      XLNX_open  XLNX_high  XLNX_low  XLNX_close  XLNX_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      XYL_open  XYL_high  XYL_low  XYL_close  XYL_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      YUM_open  YUM_high  YUM_low  YUM_close  YUM_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      ZBRA_open  ZBRA_high  ZBRA_low  ZBRA_close  ZBRA_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      ZBH_open  ZBH_high  ZBH_low  ZBH_close  ZBH_volume  \
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
#                      ZION_open  ZION_high  ZION_low  ZION_close  ZION_volume  \
# datetime
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
#
#                      ZTS_open  ZTS_high  ZTS_low  ZTS_close  ZTS_volume
# datetime
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
#
# [5 rows x 2525 columns]

# %%
spdf.shape
# Out:
# (19729, 2525)

# %%
spdf[::-1]
# Out:
#                      MMM_open  MMM_high  MMM_low  MMM_close  MMM_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      ABT_open  ABT_high  ABT_low  ABT_close  ABT_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      ABBV_open  ABBV_high  ABBV_low  ABBV_close  ABBV_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      ABMD_open  ABMD_high  ABMD_low  ABMD_close  ABMD_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      ACN_open  ACN_high  ACN_low  ACN_close  ACN_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      ATVI_open  ATVI_high  ATVI_low  ATVI_close  ATVI_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      ADBE_open  ADBE_high  ADBE_low  ADBE_close  ADBE_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      AMD_open  AMD_high  AMD_low  AMD_close  AMD_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00      81.5      81.5     81.5       81.5       609.0
#
#                      AAP_open  AAP_high  AAP_low  AAP_close  AAP_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      AES_open  AES_high  AES_low  AES_close  AES_volume  ...  \
# datetime                                                                 ...
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN  ...
# ...                       ...       ...      ...        ...         ...  ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN  ...
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN  ...
#
#                      WYNN_open  WYNN_high  WYNN_low  WYNN_close  WYNN_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      XEL_open  XEL_high  XEL_low  XEL_close  XEL_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      XRX_open  XRX_high  XRX_low  XRX_close  XRX_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      XLNX_open  XLNX_high  XLNX_low  XLNX_close  XLNX_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      XYL_open  XYL_high  XYL_low  XYL_close  XYL_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      YUM_open  YUM_high  YUM_low  YUM_close  YUM_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      ZBRA_open  ZBRA_high  ZBRA_low  ZBRA_close  ZBRA_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      ZBH_open  ZBH_high  ZBH_low  ZBH_close  ZBH_volume  \
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00       NaN       NaN      NaN        NaN         NaN
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
#                      ZION_open  ZION_high  ZION_low  ZION_close  ZION_volume  \
# datetime
# 2020-09-15 20:31:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:30:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:29:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:28:00        NaN        NaN       NaN         NaN          NaN
# 2020-09-15 20:27:00        NaN        NaN       NaN         NaN          NaN
# ...                        ...        ...       ...         ...          ...
# 2020-08-17 08:04:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:03:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:02:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:01:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-17 08:00:00        NaN        NaN       NaN         NaN          NaN
#
#                      ZTS_open  ZTS_high  ZTS_low  ZTS_close  ZTS_volume
# datetime
# 2020-09-15 20:31:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:30:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:29:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:28:00       NaN       NaN      NaN        NaN         NaN
# 2020-09-15 20:27:00    162.28    162.28   162.28     162.28      3951.0
# ...                       ...       ...      ...        ...         ...
# 2020-08-17 08:04:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:03:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:02:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:01:00       NaN       NaN      NaN        NaN         NaN
# 2020-08-17 08:00:00       NaN       NaN      NaN        NaN         NaN
#
# [19729 rows x 2525 columns]

# %%
spdf.to_csv(f'{data_dir}sp500_minute_data.csv')

# %%
spdf = pd.read_csv(f'{data_dir}sp500_minute_data.csv')

# %%
spdf[spdf.columns[spdf.isna().sum() > 1000]]

# %%
df = load_set('ABMD', data_dir, '.pickle')

df['datetime'].dtype

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df['datetime'].dtype

# %%
df.set_index('datetime', inplace=True)

# %%
df.index

# %%
spdf = pd.DataFrame()

for stock in stocks:
    df = load_set(stock, data_dir, '.pickle')
    
    df.set_index('datetime', inplace=True)
    df[f'{stock}'] = df['close'].diff(-1) / df['close']
    
    spdf[f'{stock}'] = df[f'{stock}']
    
spdf

# %%
pd.set_option('display.max_rows', 1000)

# %%
spdf[spdf.index.hour == 13]

# %%
h13 = spdf.index.hour > 13
h20 = spdf.index.hour < 20
m30 = spdf.index.minute >= 30
h12 = spdf.index.hour > 12

spdfm = spdf[h20 & (h13 | (h12 & m30))]

# %%
spdfm.head(1000)
# Out:
#                      MMM_open  MMM_high   MMM_low  MMM_close  MMM_volume  \
# datetime
# 2020-08-17 13:30:00  165.0200    165.44  164.0300   164.0800    116302.0
# 2020-08-17 13:31:00  164.1500    165.01  163.9400   164.9450     21229.0
# 2020-08-17 13:32:00  164.9700    164.97  163.6500   164.5800     64456.0
# 2020-08-17 13:33:00  164.5353    165.45  164.5353   165.4097     12810.0
# 2020-08-17 13:34:00  165.3100    166.25  165.2800   166.1460     34689.0
# ...                       ...       ...       ...        ...         ...
# 2020-08-19 17:05:00  164.8740    164.91  164.8740   164.8900      1265.0
# 2020-08-19 17:06:00  164.8500    164.85  164.7795   164.7795       550.0
# 2020-08-19 17:07:00  164.8050    164.82  164.8050   164.8200       700.0
# 2020-08-19 17:08:00  164.8055    164.82  164.8000   164.8000      2628.0
# 2020-08-19 17:09:00  164.7900    164.80  164.7700   164.7800       878.0
#
#                      ABT_open  ABT_high   ABT_low  ABT_close  ABT_volume  \
# datetime
# 2020-08-17 13:30:00       NaN       NaN       NaN        NaN         NaN
# 2020-08-17 13:31:00    100.30  100.5000  100.3000   100.3900       700.0
# 2020-08-17 13:32:00    100.38  100.5100  100.2100   100.3441     91714.0
# 2020-08-17 13:33:00    100.37  100.5500  100.2800   100.5100      4866.0
# 2020-08-17 13:34:00    100.51  100.5799  100.3500   100.3900      9128.0
# ...                       ...       ...       ...        ...         ...
# 2020-08-19 17:05:00    100.91  100.9300  100.9094   100.9300      1998.0
# 2020-08-19 17:06:00    100.93  100.9300  100.9100   100.9100      1837.0
# 2020-08-19 17:07:00    100.91  100.9400  100.9100   100.9200       550.0
# 2020-08-19 17:08:00    100.92  100.9200  100.8900   100.8900       825.0
# 2020-08-19 17:09:00    100.88  100.8800  100.8400   100.8400      1907.0
#
#                      ABBV_open  ABBV_high  ABBV_low  ABBV_close  ABBV_volume  \
# datetime
# 2020-08-17 13:30:00    95.2900    95.6200     95.29     95.3000     135895.0
# 2020-08-17 13:31:00    95.3100    95.4000     95.27     95.4000      24765.0
# 2020-08-17 13:32:00    95.4100    95.5100     95.29     95.4500      23669.0
# 2020-08-17 13:33:00    95.4550    95.4900     95.34     95.3900      16112.0
# 2020-08-17 13:34:00    95.4000    95.4700     95.30     95.3100      24926.0
# ...                        ...        ...       ...         ...          ...
# 2020-08-19 17:05:
# 2020-08-17 13:33:00     34.170    34.2276    34.150     34.2276       1600.0
# 2020-08-17 13:34:00     34.200    34.2700    34.200     34.2500       1500.0
# ...                        ...        ...       ...         ...          ...
# 2020-08-19 17:05:00     33.100    33.1000    33.100     33.1000        100.0
# 2020-08-19 17:06:00     33.075    33.0750    33.065     33.0650        879.0
# 2020-08-19 17:07:00        NaN        NaN       NaN         NaN          NaN
# 2020-08-19 17:08:00     33.065    33.0800    33.065     33.0800        644.0
# 2020-08-19 17:09:00     33.100    33.1100    33.100     33.1050       2553.0
#
#                      ZTS_open  ZTS_high  ZTS_low  ZTS_close  ZTS_volume
# datetime
# 2020-08-17 13:30:00   157.920   158.120   157.88    158.120     39460.0
# 2020-08-17 13:31:00   158.150   158.250   157.96    158.120     10481.0
# 2020-08-17 13:32:00   158.210   158.390   157.78    158.220      5503.0
# 2020-08-17 13:33:00   158.210   158.210   158.04    158.165       980.0
# 2020-08-17 13:34:00   158.175   158.540   158.03    158.080      6438.0
# ...                       ...       ...      ...        ...         ...
# 2020-08-19 17:05:00   159.510   159.510   159.44    159.440      1103.0
# 2020-08-19 17:06:00   159.410   159.450   159.41    159.450       700.0
# 2020-08-19 17:07:00   159.450   159.470   159.45    159.470       201.0
# 2020-08-19 17:08:00   159.480   159.480   159.47    159.470       675.0
# 2020-08-19 17:09:00   159.465   159.465   159.39    159.390      1000.0
#
# [1000 rows x 2525 columns]

# %%
spdfm.isna().sum().describe()
# Out:
# count    2525.000000
# mean      444.253465
# std       811.396311
# min         0.000000
# 25%         8.000000
# 50%        88.000000
# 75%       533.000000
# max      5728.000000
# dtype: float64

# %%
plt.figure(figsize=(30,30))
plt.plot(spdfm['TFX'])

# %%
spdfm['TFX'][-1000:]

# %%
spdfm.fillna(0.0, inplace=True)

# %%
spdfm.isna().sum()

# %%
plt.figure(figsize=(100,100))
for stock in spdfm.columns:
    plt.plot(spdfm[stock])

# %%
spdfm.to_pickle(f'{data_dir}spdfm.pickle')

# %%
f'{data_dir}spdfm.pickle'

# %%
spdfm = pd.read_pickle(f'{data_dir}spdfm.pickle')

# %%
X = spdfm.to_numpy()

# %%
X.shape

# %%
X

# %% [markdown]
# #### Continue downloading from loaded data
#
# Double the amount of data by opening our local file, downloading more information, and overwriting the original.

# %%
import os
import sys
from os import listdir
from os.path import isfile, join

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd 
import numpy as np
from modules.extract import extract_stock, unix_time_millis
import time

data_dir = '../data/sp500/'
stock_files = [f.split('.')[0] for f in listdir(data_dir) if isfile(join(data_dir, f))]
sp_stocks = pd.read_csv('../data/sp500/S&P500-Info.csv')['Symbol']

# %%
stock_df = pd.read_pickle('../data/sp500/MMM.pickle')
end_stamp = stock_df['datetime'].iloc[-1]
start_stamp = stock_df['datetime'].iloc[0]

# %%
stock_df
# Out:
#         open    high     low   close  volume            datetime        date  \
# 0     166.50  166.50  166.50  166.50       8 2020-09-15 20:06:00  2020-09-15
# 1     166.57  166.57  166.57  166.57  501396 2020-09-15 20:03:00  2020-09-15
# 2     168.81  168.81  168.81  168.81      12 2020-09-15 20:02:00  2020-09-15
# 3     168.40  168.40  168.20  168.20       2 2020-09-15 20:01:00  2020-09-15
# 4     166.50  166.57  166.50  166.50     300 2020-09-15 20:00:00  2020-09-15
# ...      ...     ...     ...     ...     ...                 ...         ...
# 8581  166.87  166.87  166.87  166.87     200 2020-08-17 11:51:00  2020-08-17
# 8582  166.50  166.50  166.50  166.50     302 2020-08-17 11:19:00  2020-08-17
# 8583  166.41  166.41  166.41  166.41     100 2020-08-17 11:13:00  2020-08-17
# 8584  166.11  166.11  166.11  166.11     200 2020-08-17 10:34:00  2020-08-17
# 8585  167.50  167.50  167.50  167.50     449 2020-08-17 08:39:00  2020-08-17
#
#       hour  minute  min_num SYMBOL  prev_close  diff_1  pct_change  log_return
# 0       20       6     1206    MMM      166.57   -0.07   -0.000420   -0.000420
# 1       20       3     1203    MMM      168.81   -2.24   -0.013269   -0.013358
# 2       20       2     1202    MMM      168.20    0.61    0.003627    0.003620
# 3       20       1     1201    MMM      166.50    1.70    0.010210    0.010158
# 4       20       0     1200    MMM      166.57   -0.07   -0.000420   -0.000420
# ...    ...     ...      ...    ...         ...     ...         ...         ...
# 8581    11      51      711    MMM      166.50    0.37    0.002222    0.002220
# 8582    11      19      679    MMM      166.41    0.09    0.000541    0.000541
# 8583    11      13      673    MMM      166.11    0.30    0.001806    0.001804
# 8584    10      34      634    MMM      167.50   -1.39   -0.008299   -0.008333
# 8585     8      39      519    MMM         NaN     NaN         NaN         NaN
#
# [8586 rows x 15 columns]

# %%
end_stamp > (start_stamp - pd.Timedelta('60 days'))
# Out:
# True

# %%
end_stamp -

# %%
2* (end_stamp - start_stamp)
# Out:
# Timedelta('-59 days +01:06:00')

# %%
# stock ='MMM'
# periods = 10
# end_stamp = stock_df['datetime'].iloc[-1]
# start_stamp = stock_df['datetime'].iloc[0]

# endDate = end_stamp - pd.Timedelta(days=periods)
# print(end_stamp, endDate)

# endDate = unix_time_millis(endDate)
# end_stamp = unix_time_millis(end_stamp)
extract_stock(stock,
              return_df=True,
              periodType='day', 
              frequencyType='minute', 
              frequency='1', 
              periods=periods,
              endDate=end_stamp,
              startDate=endDate)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-22-b1f49ef79cb4> in <module>
#      16               periods=periods,
#      17               endDate=end_stamp,
# ---> 18               startDate=endDate)
#
# ~/work/modules/extract.py in extract_stock(stock, data_dir, suffix, periodType, frequencyType, frequency, periods, return_df, extended, endDate, startDate, reverse)
#      84                             )
#      85
# ---> 86     stock_df = format_date(stock_data)
#      87     stock_df['SYMBOL'] = stock
#      88     stock_df = base_returns(stock_df)
#
# ~/work/modules/extract.py in format_date(data, drop)
#      51
#      52 def format_date(data, drop=True):
# ---> 53     df = pd.DataFrame(data['candles'])
#      54
#      55     df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.fromtimestamp(x/1000))
#
# KeyError: 'candles'

# %%
periods = 10 # the maximum period for the minute/day history API
stock_files = ['MMM']

for stock in stock_files: 
    stock_df = pd.read_pickle(f'{data_dir}{stock}.pickle')
    
    end_stamp = stock_df['datetime'].min()
    start_stamp = stock_df['datetime'].max()
    
    while end_stamp > (start_stamp - pd.Timedelta('60 days')):
        endDate = end_stamp - pd.Timedelta(days=periods)
        print(end_stamp, endDate)
        endDate = unix_time_millis(endDate)
        startDate = unix_time_millis(end_stamp)
        stock_df = pd.concat([stock_df, extract_stock(stock,
                                                      return_df=True,
                                                      periodType='day', 
                                                      frequencyType='minute', 
                                                      frequency='1', 
                                                      periods=periods,
                                                      endDate=startDate,
                                                      startDate=endDate)])
        
        stock_df = stock_df.sort_values(by='datetime')
        stock_df.drop_duplicates(subset='datetime')
        
        end_stamp = stock_df['datetime'].min()
        start_stamp = stock_df['datetime'].max()
        
        time.sleep(.5)
        
df
# Out:
# 2020-08-17 08:39:00 2020-08-07 08:39:00
# 2020-08-07 11:03:00 2020-07-28 11:03:00
# 2020-08-03 10:36:00 2020-07-24 10:36:00
# 2020-08-03 10:36:00 2020-07-24 10:36:00
# 2020-08-03 10:36:00 2020-07-24 10:36:00
# 2020-08-03 10:36:00 2020-07-24 10:36:00
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-337d12e733e2> in <module>
#      28         start_stamp = stock_df['datetime'].max()
#      29
# ---> 30         time.sleep(.5)
#      31
#      32 df
#
# KeyboardInterrupt:

# %%
stock_df.shape
# Out:
# (25606, 15)

# %%
stock_df.sort_values(by='datetime')
# Out:
#       open    high     low   close  volume            datetime        date  \
# 0   150.65  150.65  150.65  150.65     100 2020-08-03 10:36:00  2020-08-03
# 0   150.65  150.65  150.65  150.65     100 2020-08-03 10:36:00  2020-08-03
# 0   150.65  150.65  150.65  150.65     100 2020-08-03 10:36:00  2020-08-03
# 0   150.65  150.65  150.65  150.65     100 2020-08-03 10:36:00  2020-08-03
# 0   150.65  150.65  150.65  150.65     100 2020-08-03 10:36:00  2020-08-03
# ..     ...     ...     ...     ...     ...                 ...         ...
# 4   166.50  166.57  166.50  166.50     300 2020-09-15 20:00:00  2020-09-15
# 3   168.40  168.40  168.20  168.20       2 2020-09-15 20:01:00  2020-09-15
# 2   168.81  168.81  168.81  168.81      12 2020-09-15 20:02:00  2020-09-15
# 1   166.57  166.57  166.57  166.57  501396 2020-09-15 20:03:00  2020-09-15
# 0   166.50  166.50  166.50  166.50       8 2020-09-15 20:06:00  2020-09-15
#
#     hour  minute  min_num SYMBOL  prev_close  diff_1  pct_change  log_return
# 0     10      36      636    MMM         NaN     NaN         NaN         NaN
# 0     10      36      636    MMM         NaN     NaN         NaN         NaN
# 0     10      36      636    MMM         NaN     NaN         NaN         NaN
# 0     10      36      636    MMM         NaN     NaN         NaN         NaN
# 0     10      36      636    MMM         NaN     NaN         NaN         NaN
# ..   ...     ...      ...    ...         ...     ...         ...         ...
# 4     20       0     1200    MMM      166.57   -0.07   -0.000420   -0.000420
# 3     20       1     1201    MMM      166.50    1.70    0.010210    0.010158
# 2     20       2     1202    MMM      168.20    0.61    0.003627    0.003620
# 1     20       3     1203    MMM      168.81   -2.24   -0.013269   -0.013358
# 0     20       6     1206    MMM      166.57   -0.07   -0.000420   -0.000420
#
# [25606 rows x 15 columns]

# %%
end_stamp > (start_stamp - pd.Timedelta('60 days'))
# Out:
# False

# %%
start_stamp - pd.Timedelta('60 days')
# Out:
# Timestamp('2020-07-17 20:06:00')

# %%
end_stamp
# Out:
# Timestamp('2020-08-03 10:36:00')

# %%
spdf = pd.read_csv(f'{data_dir}sp500_minute_data.csv')

# %%
spdf
# Out:
#                   datetime  MMM_open  MMM_high  MMM_low  MMM_close  \
# 0      2020-08-17 08:00:00       NaN       NaN      NaN        NaN
# 1      2020-08-17 08:01:00       NaN       NaN      NaN        NaN
# 2      2020-08-17 08:02:00       NaN       NaN      NaN        NaN
# 3      2020-08-17 08:03:00       NaN       NaN      NaN        NaN
# 4      2020-08-17 08:04:00       NaN       NaN      NaN        NaN
# ...                    ...       ...       ...      ...        ...
# 19724  2020-09-15 20:27:00       NaN       NaN      NaN        NaN
# 19725  2020-09-15 20:28:00       NaN       NaN      NaN        NaN
# 19726  2020-09-15 20:29:00       NaN       NaN      NaN        NaN
# 19727  2020-09-15 20:30:00       NaN       NaN      NaN        NaN
# 19728  2020-09-15 20:31:00       NaN       NaN      NaN        NaN
#
#        MMM_volume  ABT_open  ABT_high  ABT_low  ABT_close  ...  ZION_open  \
# 0             NaN       NaN       NaN      NaN        NaN  ...        NaN
# 1             NaN       NaN       NaN      NaN        NaN  ...        NaN
# 2             NaN       NaN       NaN      NaN        NaN  ...        NaN
# 3             NaN       NaN       NaN      NaN        NaN  ...        NaN
# 4             NaN       NaN       NaN      NaN        NaN  ...        NaN
# ...           ...       ...       ...      ...        ...  ...        ...
# 19724         NaN       NaN       NaN      NaN        NaN  ...        NaN
# 19725         NaN       NaN       NaN      NaN        NaN  ...        NaN
# 19726         NaN       NaN       NaN      NaN        NaN  ...        NaN
# 19727         NaN       NaN       NaN      NaN        NaN  ...        NaN
# 19728         NaN       NaN       NaN      NaN        NaN  ...        NaN
#
#        ZION_high  ZION_low  ZION_close  ZION_volume  ZTS_open  ZTS_high  \
# 0            NaN       NaN         NaN          NaN       NaN       NaN
# 1            NaN       NaN         NaN          NaN       NaN       NaN
# 2            NaN       NaN         NaN          NaN       NaN       NaN
# 3            NaN       NaN         NaN          NaN       NaN       NaN
# 4            NaN       NaN         NaN          NaN       NaN       NaN
# ...          ...       ...         ...          ...       ...       ...
# 19724        NaN       NaN         NaN          NaN    162.28    162.28
# 19725        NaN       NaN         NaN          NaN       NaN       NaN
# 19726        NaN       NaN         NaN          NaN       NaN       NaN
# 19727        NaN       NaN         NaN          NaN       NaN       NaN
# 19728        NaN       NaN         NaN          NaN       NaN       NaN
#
#        ZTS_low  ZTS_close  ZTS_volume
# 0          NaN        NaN         NaN
# 1          NaN        NaN         NaN
# 2          NaN        NaN         NaN
# 3          NaN        NaN         NaN
# 4          NaN        NaN         NaN
# ...        ...        ...         ...
# 19724   162.28     162.28      3951.0
# 19725      NaN        NaN         NaN
# 19726      NaN        NaN         NaN
# 19727      NaN        NaN         NaN
# 19728      NaN        NaN         NaN
#
# [19729 rows x 2526 columns]

# %%
stock_df['datetime'].max()
# Out:
# Timestamp('2020-09-15 20:06:00')

# %%
stock_df['datetime'].min()
# Out:
# Timestamp('2020-08-17 08:39:00')

# %%
end_stamp = stock_df['datetime'].min()
start_stamp = stock_df['datetime'].max()

end_stamp, start_stamp
# Out:
# (Timestamp('2020-08-17 08:39:00'), Timestamp('2020-09-15 20:06:00'))

# %%
end_stamp > (start_stamp - pd.Timedelta('60 days'))
# Out:
# True

# %%
(start_stamp - pd.Timedelta('60 days'))
# Out:
# Timestamp('2020-07-17 20:06:00')

# %%
extract_stock('AAPL',
                                                      return_df=True,
                                                      periodType='day', 
                                                      frequencyType='minute', 
                                                      frequency='1', 
                                                      periods=periods,
                                                      endDate=None,
                                                      startDate=1505586960000)
# Out:
#            open      high       low     close  volume            datetime  \
# 0      106.8600  106.8700  106.8600  106.8700    3348 2020-08-03 08:00:00
# 1      106.9025  107.1425  106.9025  107.1425    7684 2020-08-03 08:01:00
# 2      107.1750  107.1750  107.1750  107.1750    2764 2020-08-03 08:03:00
# 3      107.1875  107.3250  107.1875  107.3250    2456 2020-08-03 08:04:00
# 4      107.3000  107.3175  107.2550  107.2550    2716 2020-08-03 08:05:00
# ...         ...       ...       ...       ...     ...                 ...
# 27670  110.3100  110.3600  110.3100  110.3600    2110 2020-09-17 23:55:00
# 27671  110.3600  110.4000  110.3600  110.3900    5107 2020-09-17 23:56:00
# 27672  110.3900  110.3900  110.3600  110.3600    1825 2020-09-17 23:57:00
# 27673  110.3700  110.3800  110.3100  110.3200    8409 2020-09-17 23:58:00
# 27674  110.3200  110.3400  110.3100  110.3400   11265 2020-09-17 23:59:00
#
#              date  hour  minute  min_num SYMBOL  prev_close  diff_1  \
# 0      2020-08-03     8       0      480   AAPL         NaN     NaN
# 1      2020-08-03     8       1      481   AAPL    106.8700  0.2725
# 2      2020-08-03     8       3      483   AAPL    107.1425  0.0325
# 3      2020-08-03     8       4      484   AAPL    107.1750  0.1500
# 4      2020-08-03     8       5      485   AAPL    107.3250 -0.0700
# ...           ...   ...     ...      ...    ...         ...     ...
# 27670  2020-09-17    23      55     1435   AAPL    110.3200  0.0400
# 27671  2020-09-17    23      56     1436   AAPL    110.3600  0.0300
# 27672  2020-09-17    23      57     1437   AAPL    110.3900 -0.0300
# 27673  2020-09-17    23      58     1438   AAPL    110.3600 -0.0400
# 27674  2020-09-17    23      59     1439   AAPL    110.3200  0.0200
#
#        pct_change  log_return
# 0             NaN         NaN
# 1        0.002550    0.002547
# 2        0.000303    0.000303
# 3        0.001400    0.001399
# 4       -0.000652   -0.000652
# ...           ...         ...
# 27670    0.000363    0.000363
# 27671    0.000272    0.000272
# 27672   -0.000272   -0.000272
# 27673   -0.000362   -0.000363
# 27674    0.000181    0.000181
#
# [27675 rows x 15 columns]

# %% [markdown]
# The data only goes back a month and a half.
#
# What kind of a joke api is this even?

# %%
endDate, startDate
# Out:
# (1595586960000, 1596450960000)

# %%
unix_time_millis(stock_df['datetime'].min())
# Out:
# 1596450960000

# %%
end_stamp = stock_df['datetime'].min()
start_stamp = stock_df['datetime'].max()

end_stamp - start_stamp
# Out:
# Timedelta('-44 days +14:30:00')

# %% [markdown]
# ### Load the sp500 dataset to BigQuery for testing

# %%
from google.cloud import bigquery 

client = bigquery.Client()

table_id = "sp500historical.info"

job_config = bigquery.LoadJobConfig(
    source_format=bigquery.SourceFormat.CSV, skip_leading_rows=1, autodetect=True,
)

with open('../data/sp500/S&P500-Info.csv', "rb") as source_file:
    job = client.load_table_from_file(source_file, table_id, job_config=job_config)

job.result()  # Waits for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 505 rows and 10 columns to sp500historical.info
