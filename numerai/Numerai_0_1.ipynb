# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkPopovich/financial-ml/blob/experiments/numerai/Numerai_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display
# !pip install gcsfs numerapi
display.clear_output()

# %%
from google.colab import drive
from google.cloud import storage
import pandas as pd
import time
import numerapi
import numpy as np
import os
import tensorflow as tf

# %%
drive.mount('/content/drive')

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/content/drive/My Drive/fin-aml/tpu-training-289520-f7727af0669b.json"

storage_client = storage.Client()
display.clear_output()

# %%
# Download the 2 numerai datasets, transform them to TFRecord, upload them to gcs bucket
bucket_path = 'gs://fin-datasets-aml/'

training_data = pd.read_csv("https://numerai-public-datasets.s3-us-west-2.amazonaws.com/latest_numerai_training_data.csv.xz")
training_data.head()
# Out:
#                  id   era  ... feature_wisdom46  target_kazutsugi
# 0  n000315175b67977  era1  ...             0.75              0.75
# 1  n0014af834a96cdd  era1  ...             1.00              0.25
# 2  n001c93979ac41d4  era1  ...             0.75              0.00
# 3  n0034e4143f22a13  era1  ...             1.00              0.00
# 4  n00679d1a636062f  era1  ...             0.75              0.75
#
# [5 rows x 314 columns]

# %%
# Out:
#                  id     era  ... feature_wisdom46  target_kazutsugi
# 0  n0003aa52cab36c2  era121  ...             0.00              0.00
# 1  n000920ed083903f  era121  ...             0.50              0.25
# 2  n0038e640522c4a6  era121  ...             0.00              1.00
# 3  n004ac94a87dc54b  era121  ...             0.25              0.75
# 4  n0052fe97ea0c05f  era121  ...             1.00              1.00
#
# [5 rows x 314 columns]

# %%
id = training_data['id']
era = training_data['era']
kind = training_data['data_type']
target = training_data['target_kazutsugi']
X = training_data.drop(['id','era','data_type','target_kazutsugi'], axis=1).to_numpy()

X[0]
# Out:
# array([0.  , 0.5 , 0.25, 0.  , 0.5 , 0.25, 0.25, 0.25, 0.75, 0.75, 0.25,
#        0.25, 1.  , 0.75, 0.5 , 1.  , 0.5 , 0.  , 0.5 , 0.5 , 0.  , 0.  ,
#        0.  , 1.  , 0.25, 0.  , 0.5 , 0.25, 0.75, 0.5 , 1.  , 0.75, 0.75,
#        0.5 , 0.5 , 0.75, 0.5 , 0.25, 0.75, 0.75, 0.5 , 0.25, 0.25, 0.5 ,
#        0.25, 0.5 , 0.25, 0.75, 0.25, 0.25, 0.5 , 0.5 , 0.75, 0.25, 0.5 ,
#        0.25, 0.5 , 0.25, 0.5 , 0.5 , 0.5 , 0.25, 0.5 , 0.25, 0.75, 0.  ,
#        0.25, 0.5 , 0.  , 0.  , 0.75, 0.5 , 0.5 , 0.25, 0.5 , 0.5 , 0.5 ,
#        0.25, 0.25, 0.25, 0.  , 0.5 , 0.5 , 0.5 , 0.5 , 0.  , 0.5 , 0.5 ,
#        0.75, 0.  , 0.5 , 0.75, 0.5 , 0.5 , 0.  , 0.75, 0.5 , 0.5 , 0.  ,
#        0.75, 0.  , 0.25, 0.75, 0.25, 0.5 , 1.  , 0.75, 0.5 , 0.  , 0.5 ,
#        0.75, 0.5 , 0.  , 0.75, 0.5 , 0.75, 0.  , 0.5 , 0.  , 0.75, 0.75,
#        0.25, 0.5 , 0.5 , 0.  , 1.  , 0.25, 0.5 , 0.75, 0.75, 0.5 , 0.75,
#        0.5 , 0.5 , 0.5 , 0.5 , 0.75, 0.75, 0.5 , 1.  , 0.75, 0.75, 1.  ,
# ...

# %%
def _floatlist_feature(value):
  return tf.train.Feature(float_list=tf.train.FloatList(value=value))

def _float_feature(value):
  return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _bytes_feature(value):
  """Returns a bytes_list from a string / byte."""
  if isinstance(value, type(tf.constant(0))):
    value = value.numpy() # BytesList won't unpack a string from an EagerTensor.
  return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _int64_feature(value):
  """Returns an int64_list from a bool / enum / int / uint."""
  return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
def serialize_example(id,era,kind,X,target):
  """
  Creates a tf.train.Example message ready to be written to a file.
  """
  # Create a dictionary mapping the feature name to the tf.train.Example-compatible
  # data type.
  feature = {
      'id': _bytes_feature(id.encode('utf-8')),
      'era': _bytes_feature(era.encode('utf-8')),
      'kind': _bytes_feature(kind.encode('utf-8')),
      'X': _floatlist_feature(X),
      'target': _float_feature(target)
  }

  # Create a Features message using tf.train.Example.

  example_proto = tf.train.Example(features=tf.train.Features(feature=feature))
  return example_proto.SerializeToString()

# %%
bucket_path = 'gs://fin-aml/data/numerai/'
filename = 'numerai_training.tfrecord'
bucket_path + filename
# Out:
# 'gs://fin-aml/data/numerai/numerai_training.tfrecord'

# %%
with tf.io.TFRecordWriter(bucket_path + filename) as writer:
  for i in range(X.shape[0]):
    example = serialize_example(id[i],era[i],kind[i],X[i],target[i])
    writer.write(example)

# %%
id[0], era[0], kind[0], target[0]
# Out:
# ('n000315175b67977', 'era1', 'train', 0.75)

# %%
### tournament data 
tournament_data = pd.read_csv("https://numerai-public-datasets.s3-us-west-2.amazonaws.com/latest_numerai_tournament_data.csv.xz")
tournament_data.head()

id = tournament_data['id']
era = tournament_data['era']
kind = tournament_data['data_type']
target = tournament_data['target_kazutsugi']
X = tournament_data.drop(['id','era','data_type','target_kazutsugi'], axis=1).to_numpy()

X[0]
# Out:
# array([0.25, 0.75, 0.5 , 0.5 , 0.  , 0.75, 0.5 , 0.25, 0.5 , 0.5 , 0.25,
#        0.  , 0.25, 0.5 , 0.25, 0.  , 0.25, 1.  , 1.  , 0.25, 1.  , 1.  ,
#        0.25, 0.25, 0.  , 0.5 , 0.25, 0.75, 0.  , 0.5 , 0.25, 0.25, 0.25,
#        0.5 , 0.  , 0.5 , 1.  , 0.25, 0.5 , 0.25, 1.  , 0.25, 0.25, 0.  ,
#        0.5 , 0.75, 0.75, 0.25, 0.25, 0.25, 0.  , 1.  , 0.5 , 1.  , 0.5 ,
#        0.25, 0.25, 0.25, 1.  , 0.  , 0.25, 0.  , 0.25, 0.25, 0.25, 1.  ,
#        0.75, 1.  , 0.  , 0.5 , 0.5 , 0.5 , 1.  , 0.25, 0.25, 0.25, 1.  ,
#        0.25, 0.25, 0.  , 1.  , 0.5 , 1.  , 0.75, 0.25, 0.25, 1.  , 0.5 ,
#        0.5 , 0.75, 0.5 , 0.25, 0.5 , 0.  , 0.25, 0.25, 0.25, 0.25, 1.  ,
#        0.75, 0.75, 1.  , 0.25, 0.5 , 0.5 , 0.75, 0.  , 0.5 , 1.  , 0.5 ,
#        0.  , 0.25, 1.  , 0.25, 0.5 , 0.75, 0.75, 1.  , 1.  , 0.  , 0.25,
#        0.75, 0.5 , 1.  , 1.  , 0.5 , 0.75, 0.5 , 0.25, 0.75, 1.  , 0.25,
#        0.5 , 0.25, 1.  , 1.  , 0.25, 0.5 , 0.75, 0.75, 1.  , 1.  , 0.75,
# ...

# %%
filename = 'numerai_tournament_1.tfrecord'

# %%
bucket_path + filename
# Out:
# 'gs://fin-aml/data/numerai/numerai_tournament_1.tfrecord'

# %%
id.shape, era.shape, kind.shape, target.shape, X.shape
# Out:
# ((1638063,), (1638063,), (1638063,), (1638063,), (1638063, 310))

# %%
with tf.io.TFRecordWriter(bucket_path + filename) as writer:
  for i in range(X.shape[0]):
    example = serialize_example(id[i],era[i],kind[i],X[i],target[i])
    writer.write(example)
